# %% [markdown]
# # Robot Arm Kinematics (2D)

# %%
# %matplotlib inline
from pylab import *
from numpy import sin, cos, pi, matrix, random
from __future__ import division
from math import atan2
rcParams['figure.figsize'] = 12, 10  # that's default image size for this interactive session
from IPython import display
#from IPython.html.widgets import interact, fixed
from ipywidgets import interact, fixed

# %% [markdown]
# ## Coordinate Transformation

# %%
def trans(x, y, a):
    '''create a 2D transformation'''
    s = sin(a)
    c = cos(a)
    return matrix([[c, -s, x],
                   [s,  c, y],
                   [0,  0, 1]])

def from_trans(m):
    '''get x, y, theta from transform matrix'''
    return [m[0, -1], m[1, -1], atan2(m[1, 0], m[0, 0])]

# %%
trans(0, 0, 0)
# Out:
# matrix([[ 1., -0.,  0.],
#         [ 0.,  1.,  0.],
#         [ 0.,  0.,  1.]])

# %% [markdown]
# ## Parameters of robot arm

# %%
N = 3  # number of links
l = [0] + range(N, 0, -1)  # length of link, l[0] is ingored
max_len = sum(l)
a = random.random_sample(N)  # angles of joints
T0 = trans(0, 0, 0)  # base

# %% [markdown]
# ## Forward Kinematics

# %%
def forward_kinematics(T0, l, a):
    T = [T0]
    for i in range(len(a)):
        Ti = T[-1] * trans(l[i], 0, a[i])
        T.append(Ti)
    Te = T[-1] * trans(l[-1], 0, 0)  # end effector
    T.append(Te)
    return T

# %%
def show_robot_arm(T):
    cla()
    x = [Ti[0,-1] for Ti in T]
    y = [Ti[1,-1] for Ti in T]
    plot(x, y, '-or', linewidth=5, markersize=10)
    xlim([-max_len, max_len])
    ylim([-max_len, max_len]) 
    ax = axes()
    ax.set_aspect('equal')
    t = atan2(T[-1][1, 0], T[-1][0,0])
    ax.annotate('[%f,%f,%f]' % (x[-1], y[-1], t), xy=(x[-1], y[-1]), xytext=(x[-1], y[-1] + 0.5))
    display.clear_output(wait=True)

# %%
for i in range(N):
    @interact(value=(-pi/2, pi/2, 0.1), n=fixed(i))
    def set_joint_angle(n, value=0):
        global a
        a[n] = value
        T = forward_kinematics(T0, l, a)
        show_robot_arm(T)

# %% [markdown]
# ## Inverse Kinematics

# %% [markdown]
# ## Analytical Solutions with Sympy

# %% [markdown]
# [SymPy](http://sympy.org/) is a Python library for symbolic mathematics.

# %%
from sympy import init_printing, sin, cos, pi, asin, acos, atan2, atan, sqrt, simplify, solve, latex, symbols
from sympy import Matrix as matrix
init_printing()

# %%
from sympy.abc import x, y, theta
trans(x, y, theta)
# Out:
# Matrix([
# [cos(theta), -sin(theta), x],
# [sin(theta),  cos(theta), y],
# [         0,           0, 1]])

# %%
N = 4
l = [symbols('l_%d' % i) for i in range(N + 1)]
l[0] = 0
a = [symbols('theta_%d' % i) for i in range(N)]
T0 = trans(0, 0, 0)

# %%
l, a
# Out:
# ([0, l_1, l_2, l_3, l_4], [theta_0, theta_1, theta_2, theta_3])

# %%
T0
# Out:
# Matrix([
# [1, 0, 0],
# [0, 1, 0],
# [0, 0, 1]])

# %%
T = forward_kinematics(T0, l, a)
Te = T[-1]
Te
# Out:
# Matrix([
# [(-(-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*sin(theta_2) + (-sin(theta_0)*cos(theta_1) - sin(theta_1)*cos(theta_0))*cos(theta_2))*sin(theta_3) + ((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*cos(theta_2) + (-sin(theta_0)*cos(theta_1) - sin(theta_1)*cos(theta_0))*sin(theta_2))*cos(theta_3), (-(-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*sin(theta_2) + (-sin(theta_0)*cos(theta_1) - sin(theta_1)*cos(theta_0))*cos(theta_2))*cos(theta_3) - ((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*cos(theta_2) + (-sin(theta_0)*cos(theta_1) - sin(theta_1)*cos(theta_0))*sin(theta_2))*sin(theta_3), l_1*cos(theta_0) + l_2*(-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1)) + l_3*((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*cos(theta_2) + (-sin(theta_0)*cos(theta_1) - sin(theta_1)*cos(theta_0))*sin(theta_2)) + l_4*((-(-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*sin(theta_2) + (-sin(theta_0)*cos(theta_1) - sin(theta_1)*cos(theta_0))*cos(theta_2))*sin(theta_3) + ((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*cos(theta_2) + (-sin(theta_0)*cos(theta_1) - sin(theta_1)*cos(theta_0))*sin(theta_2))*cos(theta_3))],
# [   ((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*sin(theta_2) + (sin(theta_0)*cos(theta_1) + sin(theta_1)*cos(theta_0))*cos(theta_2))*cos(theta_3) + ((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*cos(theta_2) - (sin(theta_0)*cos(theta_1) + sin(theta_1)*cos(theta_0))*sin(theta_2))*sin(theta_3),   -((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*sin(theta_2) + (sin(theta_0)*cos(theta_1) + sin(theta_1)*cos(theta_0))*cos(theta_2))*sin(theta_3) + ((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*cos(theta_2) - (sin(theta_0)*cos(theta_1) + sin(theta_1)*cos(theta_0))*sin(theta_2))*cos(theta_3),      l_1*sin(theta_0) + l_2*(sin(theta_0)*cos(theta_1) + sin(theta_1)*cos(theta_0)) + l_3*((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*sin(theta_2) + (sin(theta_0)*cos(theta_1) + sin(theta_1)*cos(theta_0))*cos(theta_2)) + l_4*(((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*sin(theta_2) + (sin(theta_0)*cos(theta_1) + sin(theta_1)*cos(theta_0))*cos(theta_2))*cos(theta_3) + ((-sin(theta_0)*sin(theta_1) + cos(theta_0)*cos(theta_1))*cos(theta_2) - (sin(theta_0)*cos(theta_1) + sin(theta_1)*cos(theta_0))*sin(theta_2))*sin(theta_3))],
# [                                                                                                                                                                                                                                                                                                                           0,                                                                                                                                                                                                                                                                                                                            0,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1]])

# %%
Te = simplify(Te)
Te
# Out:
# Matrix([
# [cos(theta_0 + theta_1 + theta_2 + theta_3), -sin(theta_0 + theta_1 + theta_2 + theta_3), l_1*cos(theta_0) + l_2*cos(theta_0 + theta_1) + l_3*cos(theta_0 + theta_1 + theta_2) + l_4*cos(theta_0 + theta_1 + theta_2 + theta_3)],
# [sin(theta_0 + theta_1 + theta_2 + theta_3),  cos(theta_0 + theta_1 + theta_2 + theta_3), l_1*sin(theta_0) + l_2*sin(theta_0 + theta_1) + l_3*sin(theta_0 + theta_1 + theta_2) + l_4*sin(theta_0 + theta_1 + theta_2 + theta_3)],
# [                                         0,                                           0,                                                                                                                                     1]])

# %%
eq = Te * trans(x, y, theta).inv() - T0
eq
# Out:
# Matrix([
# [(-sin(theta)**2/cos(theta) + 1/cos(theta))*cos(theta_0 + theta_1 + theta_2 + theta_3) + sin(theta)*sin(theta_0 + theta_1 + theta_2 + theta_3) - 1,     sin(theta)*cos(theta_0 + theta_1 + theta_2 + theta_3) - sin(theta_0 + theta_1 + theta_2 + theta_3)*cos(theta), l_1*cos(theta_0) + l_2*cos(theta_0 + theta_1) + l_3*cos(theta_0 + theta_1 + theta_2) + l_4*cos(theta_0 + theta_1 + theta_2 + theta_3) + (-x/cos(theta) - (-x*sin(theta)/cos(theta) + y)*sin(theta))*cos(theta_0 + theta_1 + theta_2 + theta_3) + (-x*sin(theta)/cos(theta) + y)*sin(theta_0 + theta_1 + theta_2 + theta_3)*cos(theta)],
# [    (-sin(theta)**2/cos(theta) + 1/cos(theta))*sin(theta_0 + theta_1 + theta_2 + theta_3) - sin(theta)*cos(theta_0 + theta_1 + theta_2 + theta_3), sin(theta)*sin(theta_0 + theta_1 + theta_2 + theta_3) + cos(theta)*cos(theta_0 + theta_1 + theta_2 + theta_3) - 1, l_1*sin(theta_0) + l_2*sin(theta_0 + theta_1) + l_3*sin(theta_0 + theta_1 + theta_2) + l_4*sin(theta_0 + theta_1 + theta_2 + theta_3) + (-x/cos(theta) - (-x*sin(theta)/cos(theta) + y)*sin(theta))*sin(theta_0 + theta_1 + theta_2 + theta_3) - (-x*sin(theta)/cos(theta) + y)*cos(theta)*cos(theta_0 + theta_1 + theta_2 + theta_3)],
# [                                                                                                                                                0,                                                                                                                 0,                                                                                                                                                                                                                                                                                                                                     0]])

# %%
eq = [a[0] + a[1] + a[2] - theta, eq[0, 2], eq[1, 2]]
eq
# Out:
# [-theta + theta_0 + theta_1 + theta_2,
#  l_1*cos(theta_0) + l_2*cos(theta_0 + theta_1) + l_3*cos(theta_0 + theta_1 + theta_2) + l_4*cos(theta_0 + theta_1 + theta_2 + theta_3) + (-x/cos(theta) - (-x*sin(theta)/cos(theta) + y)*sin(theta))*cos(theta_0 + theta_1 + theta_2 + theta_3) + (-x*sin(theta)/cos(theta) + y)*sin(theta_0 + theta_1 + theta_2 + theta_3)*cos(theta),
#  l_1*sin(theta_0) + l_2*sin(theta_0 + theta_1) + l_3*sin(theta_0 + theta_1 + theta_2) + l_4*sin(theta_0 + theta_1 + theta_2 + theta_3) + (-x/cos(theta) - (-x*sin(theta)/cos(theta) + y)*sin(theta))*sin(theta_0 + theta_1 + theta_2 + theta_3) - (-x*sin(theta)/cos(theta) + y)*cos(theta)*cos(theta_0 + theta_1 + theta_2 + theta_3)]

# %%
solve(eq, a)  # sympy is too stupid to solve it
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-484eedeff113> in <module>()
# ----> 1 solve(eq, a)  # sympy is too stupid to solve it
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in solve(f, *symbols, **flags)
#     909         solution = _solve(f[0], *symbols, **flags)
#     910     else:
# --> 911         solution = _solve_system(f, symbols, **flags)
#     912
#     913     #
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in _solve_system(exprs, symbols, **flags)
#    1608                 for s in ok_syms:
#    1609                     try:
# -> 1610                         soln = _solve(eq2, s, **flags)
#    1611                     except NotImplementedError:
#    1612                         continue
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in _solve(f, *symbols, **flags)
#    1296                         newf = TR1(f_num).rewrite(tan)
#    1297                         if newf != f_num:
# -> 1298                             return _solve(newf, symbol, **flags)
#    1299
#    1300                     # just a simple case - see if replacement of single function
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in _solve(f, *symbols, **flags)
#    1404         flags.pop('tsolve', None)
#    1405         try:
# -> 1406             result = _tsolve(f_num, symbol, **flags)
#    1407         except PolynomialError:
#    1408             result = None
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in _tsolve(eq, sym, **flags)
#    2295             f = factor(powdenest(lhs - rhs))
#    2296             if f.is_Mul:
# -> 2297                 return _solve(f, sym, **flags)
#    2298             if rhs:
#    2299                 f = logcombine(lhs, force=flags.get('force', True))
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in _solve(f, *symbols, **flags)
#    1154         dens = denoms(f, symbols)
#    1155         for m in f.args:
# -> 1156             soln = _solve(m, symbol, **flags)
#    1157             result.update(set(soln))
#    1158         result = list(result)
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in _solve(f, *symbols, **flags)
#    1404         flags.pop('tsolve', None)
#    1405         try:
# -> 1406             result = _tsolve(f_num, symbol, **flags)
#    1407         except PolynomialError:
#    1408             result = None
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in _tsolve(eq, sym, **flags)
#    2336         rewrite = lhs.rewrite(exp)
#    2337         if rewrite != lhs:
# -> 2338             return _solve(rewrite - rhs, sym, **flags)
#    2339     except NotImplementedError:
#    2340         pass
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in _solve(f, *symbols, **flags)
#    1216             try:
#    1217                 # try remove all...
# -> 1218                 u = unrad(f_num)
#    1219             except ValueError:
#    1220                 # ...else hope for the best while letting some remain
#
# /usr/lib/python2.7/dist-packages/sympy/solvers/solvers.pyc in unrad(eq, *syms, **flags)
#    2780     eq = powdenest(factor_terms(eq, radical=True))
#    2781     eq, d = eq.as_numer_denom()
# -> 2782     eq = _mexpand(eq)
#    2783     if _take(d):
#    2784         dens.add(d)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/sqrtdenest.pyc in _mexpand(expr)
#      11
#      12 def _mexpand(expr):
# ---> 13     return expand_mul(expand_multinomial(expr))
#      14
#      15
#
# /usr/lib/python2.7/dist-packages/sympy/core/function.pyc in expand_mul(expr, deep)
#    1986     """
#    1987     return sympify(expr).expand(deep=deep, mul=True, power_exp=False,
# -> 1988     power_base=False, basic=False, multinomial=False, log=False)
#    1989
#    1990
#
# /usr/lib/python2.7/dist-packages/sympy/core/cache.pyc in wrapper(*args, **kwargs)
#      89             def wrapper(*args, **kwargs):
#      90                 try:
# ---> 91                     retval = cfunc(*args, **kwargs)
#      92                 except TypeError:
#      93                     retval = func(*args, **kwargs)
#
# /usr/lib/python2.7/dist-packages/sympy/core/compatibility.pyc in wrapper(*args, **kwds)
#     870                         stats[HITS] += 1
#     871                         return result
# --> 872                 result = user_function(*args, **kwds)
#     873                 with lock:
#     874                     root, = nonlocal_root
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    2869             if use_hint:
#    2870                 hint = '_eval_expand_' + hint
# -> 2871                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    2872
#    2873         while True:
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2810
#    2811         if hasattr(expr, hint):
# -> 2812             newexpr = getattr(expr, hint)(**hints)
#    2813             if newexpr != expr:
#    2814                 return (newexpr, True)
#
# /usr/lib/python2.7/dist-packages/sympy/core/mul.pyc in _eval_expand_mul(self, **hints)
#     776             plain = self.func(*plain)
#     777             if sums:
# --> 778                 terms = self.func._expandsums(sums)
#     779                 args = []
#     780                 for term in terms:
#
# /usr/lib/python2.7/dist-packages/sympy/core/mul.pyc in _expandsums(sums)
#     740         terms = []
#     741         left = Mul._expandsums(sums[:L//2])
# --> 742         right = Mul._expandsums(sums[L//2:])
#     743
#     744         terms = [Mul(a, b) for a in left for b in right]
#
# /usr/lib/python2.7/dist-packages/sympy/core/mul.pyc in _expandsums(sums)
#     740         terms = []
#     741         left = Mul._expandsums(sums[:L//2])
# --> 742         right = Mul._expandsums(sums[L//2:])
#     743
#     744         terms = [Mul(a, b) for a in left for b in right]
#
# /usr/lib/python2.7/dist-packages/sympy/core/mul.pyc in _expandsums(sums)
#     742         right = Mul._expandsums(sums[L//2:])
#     743
# --> 744         terms = [Mul(a, b) for a in left for b in right]
#     745         added = Add(*terms)
#     746         return Add.make_args(added)  # it may have collapsed down to one term
#
# /usr/lib/python2.7/dist-packages/sympy/core/cache.pyc in wrapper(*args, **kwargs)
#      89             def wrapper(*args, **kwargs):
#      90                 try:
# ---> 91                     retval = cfunc(*args, **kwargs)
#      92                 except TypeError:
#      93                     retval = func(*args, **kwargs)
#
# /usr/lib/python2.7/dist-packages/sympy/core/compatibility.pyc in wrapper(*args, **kwds)
#     870                         stats[HITS] += 1
#     871                         return result
# --> 872                 result = user_function(*args, **kwds)
#     873                 with lock:
#     874                     root, = nonlocal_root
#
# /usr/lib/python2.7/dist-packages/sympy/core/operations.pyc in __new__(cls, *args, **options)
#      41         c_part, nc_part, order_symbols = cls.flatten(args)
#      42         is_commutative = not nc_part
# ---> 43         obj = cls._from_args(c_part + nc_part, is_commutative)
#      44
#      45         if order_symbols is not None:
#
# KeyboardInterrupt:

# %%
b = [symbols('theta_%d' % i) for i in range(N)]
T3 = trans(x, y, theta) * trans(l[3], 0, 0).inv()
l_1_2 = T3[0,-1] ** 2 + T3[1,-1] ** 2
b_1_2 = acos((l[1] ** 2 + l[2] ** 2 - l_1_2) / (2 * l[1] * l[2]))  # cosine rule
b[1] = pi - b_1_2
b_1 = acos((l[1] ** 2 - l[2] ** 2 + l_1_2) / (2 * l[1] * sqrt(l_1_2)))  # cosine rule
b_0 = atan(T3[1,-1] / T3[0,-1])
b[0] = b_0 - b_1
b[2] = atan(T3[1,0] / T3[0,0]) - b[0] - b[1]
B = matrix([b]).T
B = simplify(B)
B
# Out:
# Matrix([
# [                                                                                                                         -acos((l_1**2 - l_2**2 + (l_3*sin(theta) - y)**2 + (l_3*cos(theta) - x)**2)/(2*l_1*sqrt((l_3*sin(theta) - y)**2 + (l_3*cos(theta) - x)**2))) + atan((l_3*sin(theta) - y)/(l_3*cos(theta) - x))],
# [                                                                                                                                                                                                                          -acos((l_1**2 + l_2**2 - (l_3*sin(theta) - y)**2 - (l_3*cos(theta) - x)**2)/(2*l_1*l_2)) + pi],
# [acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(tan(theta)) - pi],
# [                                                                                                                                                                                                                                                                                                                theta_3]])

# %%
print latex(B)
# Out:
# \left[\begin{matrix}- \operatorname{acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} + \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}}{2 l_{1} \sqrt{\left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} + \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}}} \right )} + \operatorname{atan}{\left (\frac{l_{3} \sin{\left (\theta \right )} - y}{l_{3} \cos{\left (\theta \right )} - x} \right )}\\- \operatorname{acos}{\left (\frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(l_{3} \sin{\left (\theta \right )} - y\right)^{2} - \left(l_{3} \cos{\left (\theta \right )} - x\right)^{2}\right) \right )} + \pi\\\operatorname{acos}{\left (\frac{1}{2 l_{1} l_{2}} \left(l_{1}^{2} + l_{2}^{2} - \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} - \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}\right) \right )} + \operatorname{acos}{\left (\frac{l_{1}^{2} - l_{2}^{2} + \left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}{2 l_{1} \sqrt{\left(- l_{3} \sin{\left (\theta \right )} + y\right)^{2} + \left(- l_{3} \cos{\left (\theta \right )} + x\right)^{2}}} \right )} - \operatorname{atan}{\left (\frac{- l_{3} \sin{\left (\theta \right )} + y}{- l_{3} \cos{\left (\theta \right )} + x} \right )} + \operatorname{atan}{\left (\tan{\left (\theta \right )} \right )} - \pi\\\theta_{3}\end{matrix}\right]

# %%
T_new = forward_kinematics(T0, l, b)
Te_new = T_new[-1]
Te_new
# Out:
# Matrix([
# [((sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x))) - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)*cos(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)))/(2*l_1*l_2))*sin(acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(sin(theta)/cos(theta))) - (-sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*cos(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x))) - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)))/(2*l_1*l_2))*cos(acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(sin(theta)/cos(theta))))*sin(theta_3) + (-(sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x))) - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)*cos(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)))/(2*l_1*l_2))*cos(acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(sin(theta)/cos(theta))) - (-sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*cos(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x))) - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)))/(2*l_1*l_2))*sin(acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(sin(theta)/cos(theta))))*cos(theta_3), ((sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(the ...
# [ (-(sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x))) - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)*cos(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)))/(2*l_1*l_2))*sin(acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(sin(theta)/cos(theta))) - (sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*cos(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x))) + (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)))/(2*l_1*l_2))*cos(acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(sin(theta)/cos(theta))))*cos(theta_3) + (-(sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x))) - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)*cos(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)))/(2*l_1*l_2))*cos(acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(sin(theta)/cos(theta))) + (sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*cos(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x))) + (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)))/(2*l_1*l_2))*sin(acos((l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)/(2*l_1*l_2)) + acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(theta) + x)) + atan(sin(theta)/cos(theta))))*sin(theta_3), -(-(sqrt(1 - (l_1**2 + l_2**2 - (-l_3*sin(theta) + y)**2 - (-l_3*cos(theta) + x)**2)**2/(4*l_1**2*l_2**2))*sin(acos((l_1**2 - l_2**2 + (-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2)/(2*l_1*sqrt((-l_3*sin(theta) + y)**2 + (-l_3*cos(theta) + x)**2))) - atan((-l_3*sin(theta) + y)/(-l_3*cos(t ...
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0,                                                                                                                                                                                                                                                                                                         ...

# %%
simplify(Te_new[0, 0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-f9f0def762e9> in <module>()
# ----> 1 simplify(Te_new[0, 0])
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in simplify(expr, ratio, measure, fu)
#    3727     if expr.has(C.TrigonometricFunction) and not fu or expr.has(
#    3728             C.HyperbolicFunction):
# -> 3729         expr = trigsimp(expr, deep=True)
#    3730
#    3731     if expr.has(C.log):
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in trigsimp(expr, **opts)
#    1424                    }[method]
#    1425
# -> 1426     return trigsimpfunc(expr)
#    1427
#    1428
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in <lambda>(x)
#    1417     trigsimpfunc = {
#    1418         'fu': (lambda x: fu(x, **opts)),
# -> 1419         'matching': (lambda x: futrig(x)),
#    1420         'groebner': (lambda x: groebnersimp(x, **opts)),
#    1421         'combined': (lambda x: futrig(groebnersimp(x,
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in futrig(e, **kwargs)
#    4305
#    4306     old = e
# -> 4307     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    4308
#    4309     if kwargs.pop('hyper', True) and e.has(C.HyperbolicFunction):
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4077         if rv.args:
#    4078             args = tuple([bottom_up(a, F, atoms, nonbasic)
# -> 4079                 for a in rv.args])
#    4080             if args != rv.args:
#    4081                 rv = rv.func(*args)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4077         if rv.args:
#    4078             args = tuple([bottom_up(a, F, atoms, nonbasic)
# -> 4079                 for a in rv.args])
#    4080             if args != rv.args:
#    4081                 rv = rv.func(*args)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4077         if rv.args:
#    4078             args = tuple([bottom_up(a, F, atoms, nonbasic)
# -> 4079                 for a in rv.args])
#    4080             if args != rv.args:
#    4081                 rv = rv.func(*args)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4077         if rv.args:
#    4078             args = tuple([bottom_up(a, F, atoms, nonbasic)
# -> 4079                 for a in rv.args])
#    4080             if args != rv.args:
#    4081                 rv = rv.func(*args)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4077         if rv.args:
#    4078             args = tuple([bottom_up(a, F, atoms, nonbasic)
# -> 4079                 for a in rv.args])
#    4080             if args != rv.args:
#    4081                 rv = rv.func(*args)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4077         if rv.args:
#    4078             args = tuple([bottom_up(a, F, atoms, nonbasic)
# -> 4079                 for a in rv.args])
#    4080             if args != rv.args:
#    4081                 rv = rv.func(*args)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in bottom_up(rv, F, atoms, nonbasic)
#    4080             if args != rv.args:
#    4081                 rv = rv.func(*args)
# -> 4082             rv = F(rv)
#    4083         elif atoms:
#    4084             rv = F(rv)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in <lambda>(x)
#    4305
#    4306     old = e
# -> 4307     e = bottom_up(e, lambda x: _futrig(x, **kwargs))
#    4308
#    4309     if kwargs.pop('hyper', True) and e.has(C.HyperbolicFunction):
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in _futrig(e, **kwargs)
#    4375             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    4376         )]
# -> 4377     e = greedy(tree, objective=Lops)(e)
#    4378
#    4379     return coeff*e
#
# /usr/lib/python2.7/dist-packages/sympy/strategies/core.pyc in minrule(expr)
#     116     objective = kwargs.get('objective', identity)
#     117     def minrule(expr):
# --> 118         return min([rule(expr) for rule in rules], key=objective)
#     119     return minrule
#
# /usr/lib/python2.7/dist-packages/sympy/strategies/core.pyc in chain_rl(expr)
#      43     def chain_rl(expr):
#      44         for rule in rules:
# ---> 45             expr = rule(expr)
#      46         return expr
#      47     return chain_rl
#
# /usr/lib/python2.7/dist-packages/sympy/strategies/core.pyc in minrule(expr)
#     116     objective = kwargs.get('objective', identity)
#     117     def minrule(expr):
# --> 118         return min([rule(expr) for rule in rules], key=objective)
#     119     return minrule
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in <lambda>(x)
#    4373         TR1, TR2, TR2i,
#    4374         [identity, lambda x: _eapply(
# -> 4375             factor_terms, TR12(x), trigs)],  # expand tan of sum
#    4376         )]
#    4377     e = greedy(tree, objective=Lops)(e)
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in _eapply(func, e, cond)
#    4268         return e
#    4269     if _is_Expr(e) or not e.args:
# -> 4270         return func(e)
#    4271     return e.func(*[
#    4272         _eapply(func, ei) if (cond is None or cond(ei)) else ei
#
# /usr/lib/python2.7/dist-packages/sympy/core/exprtools.pyc in factor_terms(expr, radical, clear, fraction, sign)
#     983         return rv
#     984     expr = sympify(expr)
# --> 985     return do(expr)
#     986
#     987
#
# /usr/lib/python2.7/dist-packages/sympy/core/exprtools.pyc in do(expr)
#     976                 isprimitive=True,
#     977                 clear=clear,
# --> 978                 fraction=fraction).xreplace(special)
#     979         elif p.args:
#     980             p = p.func(
#
# /usr/lib/python2.7/dist-packages/sympy/core/exprtools.pyc in gcd_terms(terms, isprimitive, clear, fraction)
#     849             terms = sympify(terms)
#     850         terms, reps = mask(terms)
# --> 851         cont, numer, denom = _gcd_terms(terms, isprimitive, fraction)
#     852         numer = numer.xreplace(reps)
#     853         coeff, factors = cont.as_coeff_Mul()
#
# /usr/lib/python2.7/dist-packages/sympy/core/exprtools.pyc in _gcd_terms(terms, isprimitive, fraction)
#     757                 numers.append(term.coeff*numer.as_expr())
#     758         else:
# --> 759             numers = [t.as_expr() for t in terms]
#     760             denom = Term(S(1)).numer
#     761
#
# /usr/lib/python2.7/dist-packages/sympy/core/exprtools.pyc in as_expr(self)
#     647
#     648     def as_expr(self):  # Term
# --> 649         return self.coeff*(self.numer.as_expr()/self.denom.as_expr())
#     650
#     651     def mul(self, other):  # Term
#
# /usr/lib/python2.7/dist-packages/sympy/core/decorators.pyc in __sympifyit_wrapper(a, b)
#      75                 if not hasattr(b, '_op_priority'):
#      76                     b = sympify(b, strict=True)
# ---> 77                 return func(a, b)
#      78             except SympifyError:
#      79                 return retval
#
# /usr/lib/python2.7/dist-packages/sympy/core/decorators.pyc in binary_op_wrapper(self, other)
#     116                     else:
#     117                         return f(self)
# --> 118             return func(self, other)
#     119         return binary_op_wrapper
#     120     return priority_decorator
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in __div__(self, other)
#     159     @call_highest_priority('__rdiv__')
#     160     def __div__(self, other):
# --> 161         return Mul(self, Pow(other, S.NegativeOne))
#     162
#     163     @_sympifyit('other', NotImplemented)
#
# /usr/lib/python2.7/dist-packages/sympy/core/cache.pyc in wrapper(*args, **kwargs)
#      89             def wrapper(*args, **kwargs):
#      90                 try:
# ---> 91                     retval = cfunc(*args, **kwargs)
#      92                 except TypeError:
#      93                     retval = func(*args, **kwargs)
#
# /usr/lib/python2.7/dist-packages/sympy/core/compatibility.pyc in wrapper(*args, **kwds)
#     870                         stats[HITS] += 1
#     871                         return result
# --> 872                 result = user_function(*args, **kwds)
#     873                 with lock:
#     874                     root, = nonlocal_root
#
# /usr/lib/python2.7/dist-packages/sympy/core/operations.pyc in __new__(cls, *args, **options)
#      39             return args[0]
#      40
# ---> 41         c_part, nc_part, order_symbols = cls.flatten(args)
#      42         is_commutative = not nc_part
#      43         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# /usr/lib/python2.7/dist-packages/sympy/core/mul.pyc in flatten(cls, seq)
#     181                 a, b = b, a
#     182             assert not a is S.One
# --> 183             if not a.is_zero and a.is_Rational:
#     184                 r, b = b.as_coeff_Mul()
#     185                 if b.is_Add:
#
# /usr/lib/python2.7/dist-packages/sympy/core/assumptions.pyc in getit(self)
#     219             if self._assumptions is self.default_assumptions:
#     220                 self._assumptions = self.default_assumptions.copy()
# --> 221             return _ask(fact, self)
#     222
#     223     getit.func_name = as_property(fact)
#
# /usr/lib/python2.7/dist-packages/sympy/core/assumptions.pyc in _ask(fact, obj)
#     274             continue
#     275         if pk in handler_map:
# --> 276             _ask(pk, obj)
#     277
#     278             # we might have found the value of fact
#
# /usr/lib/python2.7/dist-packages/sympy/core/assumptions.pyc in _ask(fact, obj)
#     274             continue
#     275         if pk in handler_map:
# --> 276             _ask(pk, obj)
#     277
#     278             # we might have found the value of fact
#
# /usr/lib/python2.7/dist-packages/sympy/core/assumptions.pyc in _ask(fact, obj)
#     262         pass
#     263     else:
# --> 264         a = evaluate(obj)
#     265         if a is not None:
#     266             assumptions.deduce_all_facts(((fact, a),))
#
# /usr/lib/python2.7/dist-packages/sympy/core/mul.pyc in <lambda>(self)
#     958
#     959     _eval_is_finite = lambda self: _fuzzy_group(
# --> 960         a.is_finite for a in self.args)
#     961     _eval_is_commutative = lambda self: _fuzzy_group(
#     962         a.is_commutative for a in self.args)
#
# /usr/lib/python2.7/dist-packages/sympy/core/logic.pyc in _fuzzy_group(args, quick_exit)
#      50     """
#      51     saw_other = False
# ---> 52     for a in args:
#      53         if a is True:
#      54             continue
#
# /usr/lib/python2.7/dist-packages/sympy/core/mul.pyc in <genexpr>((a,))
#     958
#     959     _eval_is_finite = lambda self: _fuzzy_group(
# --> 960         a.is_finite for a in self.args)
#     961     _eval_is_commutative = lambda self: _fuzzy_group(
#     962         a.is_commutative for a in self.args)
#
# /usr/lib/python2.7/dist-packages/sympy/core/assumptions.pyc in getit(self)
#     213     """Create the automagic property corresponding to a fact."""
#     214
# --> 215     def getit(self):
#     216         try:
#     217             return self._assumptions[fact]
#
# KeyboardInterrupt:

# %%
simplify(Te_new[1, 0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-e3f3bb645c6a> in <module>()
# ----> 1 simplify(Te_new[1, 0])
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in simplify(expr, ratio, measure, fu)
#    3704     expr = bottom_up(expr, lambda w: w.normal())
#    3705     expr = Mul(*powsimp(expr).as_content_primitive())
# -> 3706     _e = cancel(expr)
#    3707     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#    3708     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# /usr/lib/python2.7/dist-packages/sympy/polys/polytools.pyc in cancel(f, *gens, **args)
#    6228
#    6229     try:
# -> 6230         (F, G), opt = parallel_poly_from_expr((p, q), *gens, **args)
#    6231     except PolificationFailed:
#    6232         if not isinstance(f, (tuple, Tuple)):
#
# /usr/lib/python2.7/dist-packages/sympy/polys/polytools.pyc in parallel_poly_from_expr(exprs, *gens, **args)
#    4123     """Construct polynomials from expressions. """
#    4124     opt = options.build_options(gens, args)
# -> 4125     return _parallel_poly_from_expr(exprs, opt)
#    4126
#    4127
#
# /usr/lib/python2.7/dist-packages/sympy/polys/polytools.pyc in _parallel_poly_from_expr(exprs, opt)
#    4175
#    4176     try:
# -> 4177         reps, opt = _parallel_dict_from_expr(exprs, opt)
#    4178     except GeneratorsNeeded:
#    4179         raise PolificationFailed(opt, origs, exprs, True)
#
# /usr/lib/python2.7/dist-packages/sympy/polys/polyutils.pyc in _parallel_dict_from_expr(exprs, opt)
#     288     """Transform expressions into a multinomial form. """
#     289     if opt.expand is not False:
# --> 290         exprs = [ expr.expand() for expr in exprs ]
#     291
#     292     if any(expr.is_commutative is False for expr in exprs):
#
# /usr/lib/python2.7/dist-packages/sympy/core/cache.pyc in wrapper(*args, **kwargs)
#      89             def wrapper(*args, **kwargs):
#      90                 try:
# ---> 91                     retval = cfunc(*args, **kwargs)
#      92                 except TypeError:
#      93                     retval = func(*args, **kwargs)
#
# /usr/lib/python2.7/dist-packages/sympy/core/compatibility.pyc in wrapper(*args, **kwds)
#     870                         stats[HITS] += 1
#     871                         return result
# --> 872                 result = user_function(*args, **kwds)
#     873                 with lock:
#     874                     root, = nonlocal_root
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    2875             if hints.get('multinomial', False):
#    2876                 expr, _ = Expr._expand_hint(
# -> 2877                     expr, '_eval_expand_multinomial', deep=deep, **hints)
#    2878             if hints.get('mul', False):
#    2879                 expr, _ = Expr._expand_hint(
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2809                 expr = expr.func(*sargs)
#    2810
# -> 2811         if hasattr(expr, hint):
#    2812             newexpr = getattr(expr, hint)(**hints)
#    2813             if newexpr != expr:
#
# KeyboardInterrupt:

# %%
simplify(Te_new[0, -1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-bf7b730f49ba> in <module>()
# ----> 1 simplify(Te_new[0, -1])
#
# /usr/lib/python2.7/dist-packages/sympy/simplify/simplify.pyc in simplify(expr, ratio, measure, fu)
#    3705     expr = Mul(*powsimp(expr).as_content_primitive())
#    3706     _e = cancel(expr)
# -> 3707     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#    3708     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#    3709
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in cancel(self, *gens, **args)
#    2985         """See the cancel function in sympy.polys"""
#    2986         from sympy.polys import cancel
# -> 2987         return cancel(self, *gens, **args)
#    2988
#    2989     def invert(self, g):
#
# /usr/lib/python2.7/dist-packages/sympy/polys/polytools.pyc in cancel(f, *gens, **args)
#    6228
#    6229     try:
# -> 6230         (F, G), opt = parallel_poly_from_expr((p, q), *gens, **args)
#    6231     except PolificationFailed:
#    6232         if not isinstance(f, (tuple, Tuple)):
#
# /usr/lib/python2.7/dist-packages/sympy/polys/polytools.pyc in parallel_poly_from_expr(exprs, *gens, **args)
#    4123     """Construct polynomials from expressions. """
#    4124     opt = options.build_options(gens, args)
# -> 4125     return _parallel_poly_from_expr(exprs, opt)
#    4126
#    4127
#
# /usr/lib/python2.7/dist-packages/sympy/polys/polytools.pyc in _parallel_poly_from_expr(exprs, opt)
#    4160
#    4161                 if opt.expand:
# -> 4162                     expr = expr.expand()
#    4163         else:
#    4164             failed = True
#
# /usr/lib/python2.7/dist-packages/sympy/core/cache.pyc in wrapper(*args, **kwargs)
#      89             def wrapper(*args, **kwargs):
#      90                 try:
# ---> 91                     retval = cfunc(*args, **kwargs)
#      92                 except TypeError:
#      93                     retval = func(*args, **kwargs)
#
# /usr/lib/python2.7/dist-packages/sympy/core/compatibility.pyc in wrapper(*args, **kwds)
#     870                         stats[HITS] += 1
#     871                         return result
# --> 872                 result = user_function(*args, **kwds)
#     873                 with lock:
#     874                     root, = nonlocal_root
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    2875             if hints.get('multinomial', False):
#    2876                 expr, _ = Expr._expand_hint(
# -> 2877                     expr, '_eval_expand_multinomial', deep=deep, **hints)
#    2878             if hints.get('mul', False):
#    2879                 expr, _ = Expr._expand_hint(
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2802             sargs = []
#    2803             for arg in expr.args:
# -> 2804                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    2805                 hit |= arghit
#    2806                 sargs.append(arg)
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in _expand_hint(expr, hint, deep, **hints)
#    2799         #              |
#    2800         #              V
# -> 2801         if deep and getattr(expr, 'args', ()) and not expr.is_Atom:
#    2802             sargs = []
#    2803             for arg in expr.args:
#
# /usr/lib/python2.7/dist-packages/sympy/core/basic.pyc in args(self)
#     619         return self.__class__
#     620
# --> 621     @property
#     622     def args(self):
#     623         """Returns a tuple of arguments of 'self'.
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test the analytical solution

# %%
from numpy import sin, cos, pi, matrix
from math import atan2, acos

T0 = trans(0, 0, 0)
lv = [0] + range(N, 0, -1)  # length of link, l[0] is ingored
bf = B
for i in range(N):
    bf = bf.subs(l[i + 1], lv[i + 1])

def inverse_kinematics(x_e, y_e, theta_e):
    b = bf.subs(x, x_e).subs(y, y_e).subs(theta, theta_e)
    b = (b.subs('I', 1).subs('pi', pi).tolist())
    try:
        b = [float(i[0]) for i in b]
    except:
        print ">>>>>>>>>>>>>>>>>>", i[0], type(i[0])
        raise
    return b
    
@interact(x_e=(0, max_len, 0.1), y_e=(-max_len, max_len, 0.1), theta_e=(-pi, pi, 0.1))
def set_end_effector(x_e=6, y_e=0, theta_e=0):
    b = inverse_kinematics(x_e, y_e, theta_e)
    T = forward_kinematics(T0, lv, b)
    show_robot_arm(T)
# Out:
# >>>>>>>>>>>>>>>>>> theta_3 <class 'sympy.core.symbol.Symbol'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-d61c801ece9f> in set_end_effector(x_e, y_e, theta_e)
#      20 @interact(x_e=(0, max_len, 0.1), y_e=(-max_len, max_len, 0.1), theta_e=(-pi, pi, 0.1))
#      21 def set_end_effector(x_e=6, y_e=0, theta_e=0):
# ---> 22     b = inverse_kinematics(x_e, y_e, theta_e)
#      23     T = forward_kinematics(T0, lv, b)
#      24     show_robot_arm(T)
#
# <ipython-input-25-d61c801ece9f> in inverse_kinematics(x_e, y_e, theta_e)
#      12     b = (b.subs('I', 1).subs('pi', pi).tolist())
#      13     try:
# ---> 14         b = [float(i[0]) for i in b]
#      15     except:
#      16         print ">>>>>>>>>>>>>>>>>>", i[0], type(i[0])
#
# /usr/lib/python2.7/dist-packages/sympy/core/expr.pyc in __float__(self)
#     223         if result.is_number and result.as_real_imag()[1]:
#     224             raise TypeError("can't convert complex to float")
# --> 225         raise TypeError("can't convert expression to float")
#     226
#     227     def __complex__(self):
#
# TypeError: can't convert expression to float

# %% [markdown]
# ### Numerical Solution

# %%
from numpy import asarray
theta = asarray([0.1] * N)
def inverse_kinematics(x_e, y_e, theta_e, theta):
    target = matrix([[x_e, y_e, theta_e]])
    while True:
        T = forward_kinematics(T0, lv, theta)
        Te = matrix([from_trans(T[-1])])
        e = target - Te
        T = matrix([from_trans(i) for i in T[1:-1]])
        J = Te - T
        J = J.T
        J[-1, :] = 1
        JJT = J * J.T
        d_theta = 0.001 * J.T * JJT.I * e.T
        #print (d_theta.T * d_theta)[0, 0]
        theta += asarray(d_theta.T)[0]
        if (d_theta.T * d_theta)[0, 0] < 1e-6:
            break
    return theta

T = forward_kinematics(T0, lv, theta)
Te = matrix([from_trans(T[-1])])

@interact(x_e=(0, max_len, 0.01), y_e=(-max_len, max_len, 0.01), theta_e=(-pi, pi, 0.01), theta=fixed(theta))
def set_end_effector(x_e=Te[0,0], y_e=Te[0,1], theta_e=Te[0,2], theta=theta):
    theta = inverse_kinematics(x_e, y_e, theta_e, theta)
    T = forward_kinematics(T0, lv, theta)
    show_robot_arm(T)
